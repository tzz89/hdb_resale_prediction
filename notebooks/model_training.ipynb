# %% [markdown]
# ## We will be focusing on using lightgbm model
# What we will be doing in this notebook
# 1. 5-fold cross validation with optuna for hyperparameter tuning
# 2. n_model ensemble prediction

# %%
#sklearn libraries
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

#models
from lightgbm import LGBMRegressor

#pandas
import pandas as pd
import numpy as np

#optimization
import optuna

#ploting lib
import plotly.express as px

#python libraries
import pickle
import json

# %%
class CONFIG:
    numeric_features= ["max_floor_lvl","floor_area_sqm","sale_year","remaining_lease_months","latitude","longitude"]
    categorical_features = ['town','flat_type','flat_model','storey_range','residential',
                            'commercial','market_hawker','miscellaneous','multistorey_carpark',
                            'precinct_pavilion',"sale_month"]
    n_splits = 10

# %% [markdown]
# ## Data preparation

# %%
preprocessed_data = pd.read_csv("../data/processed_df.csv", index_col=0)
preprocessed_data= preprocessed_data.drop_duplicates()
preprocessed_data = preprocessed_data.sample(frac=1)
preprocessed_data = preprocessed_data.reset_index(drop=True)
preprocessed_data.head()
# Out:
#            town flat_type storey_range  floor_area_sqm flat_model  \
# 0      SENGKANG    4 ROOM     13 TO 15            95.0    Model A
# 1    QUEENSTOWN    3 ROOM     01 TO 03            67.0   Improved
# 2  CENTRAL AREA    3 ROOM     07 TO 09            60.0   Improved
# 3   JURONG EAST    4 ROOM     04 TO 06           101.0    Model A
# 4         BEDOK    3 ROOM     04 TO 06            68.0   Improved
#
#    resale_price  max_floor_lvl residential commercial market_hawker  \
# 0      475000.0           17.0           Y          N             N
# 1      358000.0           10.0           Y          N             N
# 2      425000.0           21.0           Y          N             N
# 3      428000.0           10.0           Y          N             N
# 4      315000.0           15.0           Y          Y             N
#
#   miscellaneous multistorey_carpark precinct_pavilion  latitude   longitude  \
# 0             Y                   N                 N  1.382595  103.902573
# 1             Y                   N                 N  1.306485  103.796500
# 2             N                   N                 N  1.298768  103.852176
# 3             N                   N                 N  1.341967  103.746945
# 4             N                   N                 N  1.323405  103.941168
#
#    sale_month  sale_year  remaining_lease_months
# 0           1       2013                    1032
# 1           8       2021                     621
# 2           8       2016                     732
# 3           7       2018                     954
# 4           6       2016                     816

# %%
preprocessed_data
# Out:
#                 town  flat_type storey_range  floor_area_sqm  \
# 0           SENGKANG     4 ROOM     13 TO 15            95.0
# 1         QUEENSTOWN     3 ROOM     01 TO 03            67.0
# 2       CENTRAL AREA     3 ROOM     07 TO 09            60.0
# 3        JURONG EAST     4 ROOM     04 TO 06           101.0
# 4              BEDOK     3 ROOM     04 TO 06            68.0
# ...              ...        ...          ...             ...
# 184162     WOODLANDS     3 ROOM     10 TO 12            88.0
# 184163        YISHUN     5 ROOM     07 TO 09           121.0
# 184164   BUKIT BATOK  EXECUTIVE     01 TO 03           148.0
# 184165      SENGKANG     4 ROOM     13 TO 15            90.0
# 184166      SENGKANG     4 ROOM     16 TO 18            94.0
#
#                flat_model  resale_price  max_floor_lvl residential commercial  \
# 0                 Model A      475000.0           17.0           Y          N
# 1                Improved      358000.0           10.0           Y          N
# 2                Improved      425000.0           21.0           Y          N
# 3                 Model A      428000.0           10.0           Y          N
# 4                Improved      315000.0           15.0           Y          Y
# ...                   ...           ...            ...         ...        ...
# 184162     New Generation      275000.0           14.0           Y          N
# 184163           Improved      498000.0           12.0           Y          N
# 184164         Maisonette      580000.0            4.0           Y          N
# 184165           Model A2      440000.0           15.0           Y          N
# 184166  Premium Apartment      447000.0           17.0           Y          N
#
#        market_hawker miscellaneous multistorey_carpark precinct_pavilion  \
# 0                  N             Y                   N                 N
# 1                  N             Y                   N                 N
# 2                  N             N                   N                 N
# 3                  N             N                   N                 N
# 4                  N             N                   N                 N
# ...              ...           ...                 ...               ...
# 184162             N             Y                   N                 N
# 184163             N             N                   N                 N
# 184164             N             N                   N                 N
# 184165             N             Y                   N                 N
# 184166             N             Y                   N                 N
#
#         latitude   longitude  sale_month  sale_year  remaining_lease_months
# 0       1.382595  103.902573           1       2013                    1032
# 1       1.306485  103.796500           8       2021                     621
# 2       1.298768  103.852176           8       2016                     732
# 3       1.341967  103.746945           7       2018                     954
# 4       1.323405  103.941168           6       2016                     816
# ...          ...         ...         ...        ...                     ...
# 184162  1.443349  103.772944           3       2018                     730
# 184163  1.431353  103.837696           1       2016                     816
# 184164  1.361721  103.749848           7       2020                     777
# 184165  1.393844  103.897494           5       2018                     980
# 184166  1.395962  103.902377           6       2012                    1056
#
# [184167 rows x 18 columns]

# %%
features = preprocessed_data.drop("resale_price", axis=1)
target = preprocessed_data['resale_price']

# %% [markdown]
# ## Model
# We are going to wrap all the construction into optuna objective

# %%
def get_model(model_args):
    #numeric_transformer
    numeric_transformer = Pipeline(steps=[
        ("normalize", StandardScaler()),
        ("polyfeatures", PolynomialFeatures())
    ])

    #categorical_transformer
    categorical_transformer = Pipeline(steps=[
        ("onehotencoding", OneHotEncoder(drop='first'))
    ])


    # Column transformer
    preprocessing = ColumnTransformer(transformers=[
        ('numerical_columns', numeric_transformer, CONFIG.numeric_features),
        ("categorical_column", categorical_transformer, CONFIG.categorical_features)
    ])

    #model definition and optuna suggestions
    #following the documentation at https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html, we will
    #be tuning 3 important hyperparameters 1. num_leaves 2. min_data_in_leaf  3. max_depth
    
    model = LGBMRegressor(**model_args)

    # main pipeline
    full_model_pipeline = Pipeline(steps=[
        ("preprocessing", preprocessing),
        ("clf", model)
    ])
    
    return full_model_pipeline

# %%
def objective(trial):
    num_leaves = trial.suggest_int("num_leaves",19,25,step=2)
    n_estimators = trial.suggest_int("n_estimators",2000,6000, step=100)
#     min_data_in_leaf  = trial.suggest_int("min_data_in_leaf",100,2000, step=250)
#     max_depth = trial.suggest_int("max_depth",7,13,step=2)
    learning_rate = trial.suggest_loguniform("learning_rate", 0.01,0.3)
    
    model_args={'num_leaves': num_leaves, 
                'n_estimators': n_estimators, 
                'max_depth': -1, 
                'learning_rate': learning_rate,
                "metric" : "rmse"}
    
    full_model_pipeline = get_model(model_args)
    
    mape = -1.0* np.mean(cross_val_score(full_model_pipeline,features,target,cv=5,scoring='neg_root_mean_squared_error'))
    
    return mape

# %%
study=optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=35)
# Out:
# [I 2021-12-02 20:41:36,680] A new study created in memory with name: no-name-61c28aa1-cc70-4d6c-884c-5ef1f614dc5b
# [I 2021-12-02 20:45:05,057] Trial 0 finished with value: 24722.108452252105 and parameters: {'num_leaves': 23, 'n_estimators': 3500, 'learning_rate': 0.016193027448381463}. Best is trial 0 with value: 24722.108452252105.
# [I 2021-12-02 20:48:04,533] Trial 1 finished with value: 22421.625731660897 and parameters: {'num_leaves': 19, 'n_estimators': 4000, 'learning_rate': 0.13599971927365137}. Best is trial 1 with value: 22421.625731660897.
# [I 2021-12-02 20:52:26,980] Trial 2 finished with value: 22373.38288908499 and parameters: {'num_leaves': 21, 'n_estimators': 5400, 'learning_rate': 0.055445061007302204}. Best is trial 2 with value: 22373.38288908499.
# [I 2021-12-02 20:57:21,544] Trial 3 finished with value: 23439.20520299997 and parameters: {'num_leaves': 21, 'n_estimators': 5600, 'learning_rate': 0.020186195097758042}. Best is trial 2 with value: 22373.38288908499.
# [I 2021-12-02 21:01:30,120] Trial 4 finished with value: 22432.058894239508 and parameters: {'num_leaves': 21, 'n_estimators': 5100, 'learning_rate': 0.0534001085095719}. Best is trial 2 with value: 22373.38288908499.
# [I 2021-12-02 21:04:19,000] Trial 5 finished with value: 22416.98277836289 and parameters: {'num_leaves': 23, 'n_estimators': 3400, 'learning_rate': 0.0774872133061327}. Best is trial 2 with value: 22373.38288908499.
# [I 2021-12-02 21:06:17,298] Trial 6 finished with value: 23093.55378374686 and parameters: {'num_leaves': 25, 'n_estimators': 2500, 'learning_rate': 0.2843194029661194}. Best is trial 2 with value: 22373.38288908499.
# [I 2021-12-02 21:10:46,268] Trial 7 finished with value: 23978.142844540234 and parameters: {'num_leaves': 21, 'n_estimators': 3900, 'learning_rate': 0.02249511991482005}. Best is trial 2 with value: 22373.38288908499.
# [I 2021-12-02 21:15:11,661] Trial 8 finished with value: 22573.06821288121 and parameters: {'num_leaves': 23, 'n_estimators': 4800, 'learning_rate': 0.0413209188878253}. Best is trial 2 with value: 22373.38288908499.
# [I 2021-12-02 21:19:01,000] Trial 9 finished with value: 22504.997726571804 and parameters: {'num_leaves': 23, 'n_estimators': 4300, 'learning_rate': 0.04962915115149537}. Best is trial 2 with value: 22373.38288908499.
# [I 2021-12-02 21:25:17,054] Trial 10 finished with value: 25050.76834158277 and parameters: {'num_leaves': 19, 'n_estimators': 6000, 'learning_rate': 0.010348475050628027}. Best is trial 2 with value: 22373.38288908499.
# [I 2021-12-02 21:27:53,698] Trial 11 finished with value: 22386.623309780898 and parameters: {'num_leaves': 25, 'n_estimators': 2700, 'learning_rate': 0.10453121687324513}. Best is trial 2 with value: 22373.38288908499.
# [I 2021-12-02 21:29:47,488] Trial 12 finished with value: 22577.044504840895 and parameters: {'num_leaves': 25, 'n_estimators': 2000, 'learning_rate': 0.11362754186015724}. Best is trial 2 with value: 22373.38288908499.
# [I 2021-12-02 21:32:20,155] Trial 13 finished with value: 22594.7196547598 and parameters: {'num_leaves': 25, 'n_estimators': 2800, 'learning_rate': 0.1847096957186782}. Best is trial 2 with value: 22373.38288908499.
# [I 2021-12-02 21:36:29,496] Trial 14 finished with value: 22313.817370026398 and parameters: {'num_leaves': 21, 'n_estimators': 5000, 'learning_rate': 0.086093249019348}. Best is trial 14 with value: 22313.817370026398.
# [I 2021-12-02 21:41:16,354] Trial 15 finished with value: 22750.984340717845 and parameters: {'num_leaves': 21, 'n_estimators': 5100, 'learning_rate': 0.03657410298324044}. Best is trial 14 with value: 22313.817370026398.
# [I 2021-12-02 21:44:50,267] Trial 16 finished with value: 22389.412719154672 and parameters: {'num_leaves': 19, 'n_estimators': 4600, 'learning_rate': 0.07508664856695006}. Best is trial 14 with value: 22313.817370026398.
# [I 2021-12-02 21:49:39,984] Trial 17 finished with value: 22799.035833173126 and parameters: {'num_leaves': 21, 'n_estimators': 5600, 'learning_rate': 0.031081592171473677}. Best is trial 14 with value: 22313.817370026398.
# [I 2021-12-02 21:53:53,183] Trial 18 finished with value: 22349.245888111644 and parameters: {'num_leaves': 19, 'n_estimators': 5500, 'learning_rate': 0.066766693468857}. Best is trial 14 with value: 22313.817370026398.
# [I 2021-12-02 21:58:09,542] Trial 19 finished with value: 22657.989989247686 and parameters: {'num_leaves': 19, 'n_estimators': 5900, 'learning_rate': 0.17601669109483484}. Best is trial 14 with value: 22313.817370026398.
# [I 2021-12-02 22:01:48,821] Trial 20 finished with value: 22353.164597581905 and parameters: {'num_leaves': 19, 'n_estimators': 4800, 'learning_rate': 0.07892973103236484}. Best is trial 14 with value: 22313.817370026398.
# [I 2021-12-02 22:05:33,313] Trial 21 finished with value: 22366.49693802941 and parameters: {'num_leaves': 19, 'n_estimators': 4900, 'learning_rate': 0.0727439060728665}. Best is trial 14 with value: 22313.817370026398.
# [I 2021-12-02 22:08:58,690] Trial 22 finished with value: 22354.18136423329 and parameters: {'num_leaves': 19, 'n_estimators': 4500, 'learning_rate': 0.09200457721927029}. Best is trial 14 with value: 22313.817370026398.
# [I 2021-12-02 22:12:51,535] Trial 23 finished with value: 22471.245126663922 and parameters: {'num_leaves': 19, 'n_estimators': 5300, 'learning_rate': 0.14701316371034495}. Best is trial 14 with value: 22313.817370026398.
# [I 2021-12-02 22:17:09,050] Trial 24 finished with value: 22340.589699575667 and parameters: {'num_leaves': 19, 'n_estimators': 5600, 'learning_rate': 0.06352887262848994}. Best is trial 14 with value: 22313.817370026398.
# [I 2021-12-02 22:21:42,420] Trial 25 finished with value: 22277.10590765158 and parameters: {'num_leaves': 21, 'n_estimators': 5800, 'learning_rate': 0.06205015857912911}. Best is trial 25 with value: 22277.10590765158.
# [I 2021-12-02 22:26:36,208] Trial 26 finished with value: 22847.614343020912 and parameters: {'num_leaves': 21, 'n_estimators': 5800, 'learning_rate': 0.028901516378372752}. Best is trial 25 with value: 22277.10590765158.
# [I 2021-12-02 22:30:49,763] Trial 27 finished with value: 22506.000587811603 and parameters: {'num_leaves': 21, 'n_estimators': 5200, 'learning_rate': 0.046898282982325866}. Best is trial 25 with value: 22277.10590765158.
# [I 2021-12-02 22:35:07,515] Trial 28 finished with value: 23422.073103836352 and parameters: {'num_leaves': 23, 'n_estimators': 5700, 'learning_rate': 0.2673969410504243}. Best is trial 25 with value: 22277.10590765158.
# [I 2021-12-02 22:39:50,848] Trial 29 finished with value: 22294.523275797394 and parameters: {'num_leaves': 21, 'n_estimators': 6000, 'learning_rate': 0.060045954160190644}. Best is trial 25 with value: 22277.10590765158.
# [I 2021-12-02 22:44:30,782] Trial 30 finished with value: 22338.876665386208 and parameters: {'num_leaves': 23, 'n_estimators': 6000, 'learning_rate': 0.10249957902909722}. Best is trial 25 with value: 22277.10590765158.
# [I 2021-12-02 22:49:08,499] Trial 31 finished with value: 22335.39286603898 and parameters: {'num_leaves': 23, 'n_estimators': 6000, 'learning_rate': 0.09746255961369335}. Best is trial 25 with value: 22277.10590765158.
# [I 2021-12-02 22:53:41,864] Trial 32 finished with value: 22421.42299422801 and parameters: {'num_leaves': 21, 'n_estimators': 6000, 'learning_rate': 0.1188895910467804}. Best is trial 25 with value: 22277.10590765158.
# [I 2021-12-02 22:57:57,044] Trial 33 finished with value: 22270.37739466198 and parameters: {'num_leaves': 23, 'n_estimators': 5400, 'learning_rate': 0.09069317714796007}. Best is trial 33 with value: 22270.37739466198.
# [I 2021-12-02 23:01:58,334] Trial 34 finished with value: 22453.568019973878 and parameters: {'num_leaves': 21, 'n_estimators': 5300, 'learning_rate': 0.13704863646593463}. Best is trial 33 with value: 22270.37739466198.

# %%
print(study.best_trial)
# Out:
# FrozenTrial(number=33, values=[22270.37739466198], datetime_start=datetime.datetime(2021, 12, 2, 22, 53, 41, 864093), datetime_complete=datetime.datetime(2021, 12, 2, 22, 57, 57, 44626), params={'num_leaves': 23, 'n_estimators': 5400, 'learning_rate': 0.09069317714796007}, distributions={'num_leaves': IntUniformDistribution(high=25, low=19, step=2), 'n_estimators': IntUniformDistribution(high=6000, low=2000, step=100), 'learning_rate': LogUniformDistribution(high=0.3, low=0.01)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=33, state=TrialState.COMPLETE, value=None)

# %% [markdown]
# ## Ensembling model based on best params
# {'num_leaves': 23, 'n_estimators': 5400, 'learning_rate': 0.09069317714796007}

# %% [markdown]
# ### Testing the performance of 1 model

# %%
best_params = {'num_leaves': 23, 'n_estimators': 5400, 'learning_rate': 0.09069317714796007}
full_model_pipeline = get_model(best_params)

X_train, X_text, y_train, y_test = train_test_split(features, target, train_size=0.9, random_state=42)
full_model_pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('numerical_columns',
#                                                   Pipeline(steps=[('normalize',
#                                                                    StandardScaler()),
#                                                                   ('polyfeatures',
#                                                                    PolynomialFeatures())]),
#                                                   ['max_floor_lvl',
#                                                    'floor_area_sqm',
#                                                    'sale_year',
#                                                    'remaining_lease_months',
#                                                    'latitude', 'longitude']),
#                                                  ('categorical_column',
#                                                   Pipeline(steps=[('onehotencoding',
#                                                                    OneHotEncoder(drop='first'))]),
#                                                   ['town', 'flat_type',
#                                                    'flat_model', 'storey_range',
#                                                    'residential', 'commercial',
#                                                    'market_hawker',
#                                                    'miscellaneous',
#                                                    'multistorey_carpark',
#                                                    'precinct_pavilion',
#                                                    'sale_month'])])),
#                 ('clf',
#                  LGBMRegressor(learning_rate=0.09069317714796007,
#                                n_estimators=5400, num_leaves=23))])

# %%
y_pred = full_model_pipeline.predict(X_text)

# %%
px.scatter(x=y_pred,y=y_test,title="Actual against Prediction")
# Out:
# <div>                            <div id="fa6746bf-0a28-4c9f-9c91-d5b5f084e0d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa6746bf-0a28-4c9f-9c91-d5b5f084e0d4")) {                    Plotly.newPlot(                        "fa6746bf-0a28-4c9f-9c91-d5b5f084e0d4",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[447691.59712283616,501592.8224163547,694789.0380217722,487269.81752525695,427745.16181639227,865273.5576127443,372307.96799364634,496980.0022413009,387016.93329659104,542531.1019023488,423982.514839722,369430.0800745095,465681.2179928554,382192.6859684244,465855.9119118939,482994.1420623405,396872.221423705,649513.7223991925,442531.230512792,700563.834473657,265304.2977219442,493229.33206131257,413000.3725609687,622765.4458745329,369118.10924901656,376109.68014408153,478900.85459272104,472871.62016448454,451914.62366794073,417292.0227953164,253798.5071220811,521116.48671502015,302208.8882925704,416015.6964489876,581595.6465218721,511463.70172123535,445353.53519869334,363920.4933267294,755269.0619925209,473278.23973601405,309995.16422631417,439238.4593958911,387426.31563387107,571743.1996131933,335423.52543923934,709665.6641275558,733292.065929029,667047.0022632177,280622.13809038256,577356.1039137861,344102.4439334495,307979.6186471249,476119.2194929059,325044.2758640963,380265.7652364916,409742.5292095207,235649.0403595361,437451.9241717723,592499.9533547238,498368.72460992367,419242.9916039197,620494.177957929,416782.42796065606,868840.3217100827,275150.93703387683,321789.15216784494,239631.38786730336,333378.07645732857,399885.5785194393,370316.2084091857,440225.4552635288,754656.5353943843,293649.7154811198,340885.2444048996,353283.859671533,464190.7041474315,538253.9260387984,391166.8309487001,529293.226910451,284565.3040250555,329107.7977520067,334362.8299478735,394147.0407493945,320056.37534860964,298475.34217976907,392710.8057071017,249815.38198856564,618219.5707459294,365666.8715053218,688928.4517684318,413531.757962961,361787.4357668786,376670.05773427035,464743.69088015315,396442.0017449711,364867.0355918062,551543.5941053596,429655.7057772385,247089.20446224912,336613.2948714132,315620.9567607122,440806.37277800037,823266.5235824455,669749.993981655,472435.09257008333,469689.3428220417,379605.77110429946,584900.0423822233,421078.5336661198,547562.4060390689,585708.0367742324,613330.3824792068,271073.44356353715,384105.6578925379,428475.5046039395,385727.1793639924,232854.2252062254,485591.65261358395,268893.72893177456,715220.2533996945,316901.34772748785,553370.2748206566,550388.1521025285,436626.09123262425,389517.0983760871,229929.08323641052,460689.70392940554,535687.6211298568,368109.2837917851,637193.7285471737,303759.64072318736,407016.755351662,468076.2354221299,394598.39822084754,351838.5684288066,506240.65505763394,520749.4814590953,325583.9128609837,446453.4776590638,301755.2809913977,550273.609789617,622371.0735774083,691273.9940131754,424408.26231278427,931643.2507065036,305018.197527395,364971.8975404079,313305.7634770546,399745.8839597371,453624.7484959232,330683.2558007879,413621.0114607549,644598.1342770517,522787.4773886582,438224.4103967147,227391.48844911123,318209.3031759113,536204.82757806,303863.8677150134,281999.1070743486,274037.09103353426,355723.1762612141,677391.97774085,636475.4091347712,315748.6915089905,270598.06069038156,539760.4116657712,388761.17791973747,364944.7387683431,581221.6109684899,449226.1718462962,695993.0198530435,784301.3939861535,482377.76165588526,574414.6982318737,498729.92862949887,480358.83192935714,444815.33716307016,406370.1576397608,377347.86363981524,347533.33213020564,659853. ...

# %% [markdown]
# ## Ensembling 10 models with 10 fold cv
# As we can see from above, the housing cost is not evenly distributed and therefore, we are going create a stratifiedKfold for continuous variable

# %%
class ContinuousStratifiedKFold(StratifiedKFold):
    #using parent init
    def split(self,X,y,groups=None):
        #using the same signature as original
        n_bins = 8
        bins = pd.cut(y, bins=n_bins, labels=False)
        return super().split(X,bins,groups=groups)

# %%
fold_splitter = ContinuousStratifiedKFold(n_splits=CONFIG.n_splits,shuffle=True, random_state=42)

result_log = {}
y_test_log = []
y_pred_log = []

for n_fold, (train_idx,test_idx) in enumerate(fold_splitter.split(features, target)):
    print(f"Training fold:{n_fold}")
    X_train=features.iloc[train_idx]
    y_train = target.iloc[train_idx]
    
    X_test = features.iloc[test_idx]
    y_test = target.iloc[test_idx]
    y_test_log.append(y_test)
    
    model_pipeline = get_model(best_params)
    model_pipeline.fit(X_train,y_train)
    y_pred = model_pipeline.predict(X_test)
    y_pred_log.append(y_pred)

    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mae = mean_absolute_error(y_test, y_pred)
    mape = mean_absolute_percentage_error(y_test,y_pred)
    
    result_dict = dict(rmse=rmse, mae=mae, mape=mape)
    print(result_dict)
    result_log[n_fold] = result_dict
    
    #saving model
    model_dir = f"../artifacts/model_pipeline_fold_{n_fold}.pkl"
    with open(model_dir, 'wb') as pklfile:
        pickle.dump(model_pipeline, pklfile, protocol=pickle.HIGHEST_PROTOCOL)
        print("Model saved")
# Out:
# Training fold:0
# {'rmse': 22056.706245250327, 'mae': 15924.466850176379, 'mape': 0.03624192949624733}
# Model saved
# Training fold:1
# {'rmse': 21831.137152816664, 'mae': 15839.181135665893, 'mape': 0.03597396064225636}
# Model saved
# Training fold:2
# {'rmse': 21901.69226723495, 'mae': 15844.617766010837, 'mape': 0.03601755374828156}
# Model saved
# Training fold:3
# {'rmse': 22109.457708187096, 'mae': 16045.02300710227, 'mape': 0.03642136873567148}
# Model saved
# Training fold:4
# {'rmse': 22291.40688218235, 'mae': 16077.142763416807, 'mape': 0.036554949785866424}
# Model saved
# Training fold:5
# {'rmse': 22535.31566354448, 'mae': 16085.409047851272, 'mape': 0.036364743323599284}
# Model saved
# Training fold:6
# {'rmse': 22097.103341971397, 'mae': 16003.715874020243, 'mape': 0.03629088747634874}
# Model saved
# Training fold:7
# {'rmse': 22100.2137036957, 'mae': 16006.388303144073, 'mape': 0.036239992117598326}
# Model saved
# Training fold:8
# {'rmse': 22072.112464300117, 'mae': 15938.281357533724, 'mape': 0.03613136359906501}
# Model saved
# Training fold:9
# {'rmse': 22187.618226916533, 'mae': 15983.416906972594, 'mape': 0.03618750978090735}
# Model saved

# %%
## saving results
with open("../artifacts/metrics_result.json", 'w') as jsonfile:
    json.dump(result_log, jsonfile)
